# %%
"""
Extracción de ficheros .csv de Yfinance, cada comentario se indica qué tipo de información contienen
"""
# Out:
# '\nExtracción de ficheros .csv de Yfinance, cada comentario se indica qué tipo de información contienen\n'

# %%
#pip install yfinance
#pip install finplot
#pip install matplotlib

# %%
import yfinance as yf
import pandas as pd
from datetime import datetime

# %%
#exploración de los datos que existen de una acción
ticker = "NVDA"
stock = yf.Ticker(ticker)
stock_info = stock.info

for line in stock_info.items():
    print("-", line)
# Out:
# - ('address1', '2788 San Tomas Expressway')
# - ('city', 'Santa Clara')
# - ('state', 'CA')
# - ('zip', '95051')
# - ('country', 'United States')
# - ('phone', '408 486 2000')
# - ('website', 'https://www.nvidia.com')
# - ('industry', 'Semiconductors')
# - ('industryKey', 'semiconductors')
# - ('industryDisp', 'Semiconductors')
# - ('sector', 'Technology')
# - ('sectorKey', 'technology')
# - ('sectorDisp', 'Technology')
# ...

# %%
#identificación de las empresas del sector de tecnológico
sector = yf.Sector("technology").top_companies
sector = sector.reset_index().rename(columns={"index": "symbol"})
tech_tickers_list = sector["symbol"].tolist()

print(tech_tickers_list)
# Out:
# ['AAPL', 'NVDA', 'MSFT', 'AVGO', 'ORCL', 'CRM', 'AMD', 'ACN', 'CSCO', 'ADBE', 'NOW', 'TXN', 'IBM', 'QCOM', 'INTU', 'UBER', 'AMAT', 'ANET', 'ADP', 'PANW', 'MU', 'FI', 'ADI', 'LRCX', 'PLTR', 'INTC', 'KLAC', 'DELL', 'APH', 'SNPS', 'CDNS', 'MSI', 'CRWD', 'MRVL', 'NXPI', 'ADSK', 'WDAY', 'FTNT', 'TTD', 'ROP', 'APP', 'PAYX', 'TEAM', 'FICO', 'MSTR', 'FIS', 'TEL', 'SQ', 'MPWR', 'DDOG']

# %%
#lista de tickers del sector tecnológico
def input_tickers():
    print("Lista de tickers tecnológicos disponibles:")
    for i, ticker in enumerate(tech_tickers_list, start=1):
        print(f"{i}. {ticker}")

    # Solicitar al usuario los números de los tickers deseados
    selected_numbers = input("Introduce los números de los tickers separados por comas (ej. 1, 3, 5): ")
    
    # Convertir la entrada en una lista de tickers
    selected_tickers = [tech_tickers_list[int(num.strip()) - 1] for num in selected_numbers.split(",") if num.strip().isdigit()]
    
    return selected_tickers

# %%
#solicitar tickers al usuario
tickers = input_tickers()
# Out:
# Lista de tickers tecnológicos disponibles:
# 1. AAPL
# 2. NVDA
# 3. MSFT
# 4. AVGO
# 5. ORCL
# 6. CRM
# 7. AMD
# 8. ACN
# 9. CSCO
# 10. ADBE
# 11. NOW
# 12. TXN
# 13. IBM
# 14. QCOM
# 15. INTU
# 16. UBER
# 17. AMAT
# 18. ANET
# 19. ADP
# 20. PANW
# 21. MU
# 22. FI
# 23. ADI
# 24. LRCX
# 25. PLTR
# 26. INTC
# 27. KLAC
# 28. DELL
# 29. APH
# 30. SNPS
# 31. CDNS
# 32. MSI
# 33. CRWD
# 34. MRVL
# 35. NXPI
# 36. ADSK
# 37. WDAY
# 38. FTNT
# 39. TTD
# 40. ROP
# 41. APP
# 42. PAYX
# 43. TEAM
# 44. FICO
# 45. MSTR
# 46. FIS
# 47. TEL
# 48. SQ
# 49. MPWR
# 50. DDOG
# Introduce los números de los tickers separados por comas (ej. 1, 3, 5):  1,2,3,4,5

# %%
#ver tickers seleccionados
tickers
# Out:
# ['AAPL', 'NVDA', 'MSFT', 'AVGO', 'ORCL']

# %%
def get_historical_prices(tickers):
    all_data = []  #almacenar los df individuales de cada ticker
    
    for ticker in tickers:
        historical_prices = yf.download(ticker)
        historical_prices = historical_prices.reset_index()
        
        #añadir valor del ticker para todas las filas
        historical_prices["ticker"] = ticker
        
        #añadir timestamp
        extraction_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        historical_prices["extraction_timestamp"] = pd.to_datetime(extraction_time)
        
        #renombrar las columnas
        historical_prices.columns = ["date", "open", "high", "low", "close", "adj_close", "volume", "ticker", "extraction_timestamp"]
        
        #transformación de datos
        historical_prices["date"] = pd.to_datetime(historical_prices["date"]).dt.date
        historical_prices["open"] = historical_prices["open"].astype(float)
        historical_prices["high"] = historical_prices["high"].astype(float)
        historical_prices["low"] = historical_prices["low"].astype(float)
        historical_prices["close"] = historical_prices["close"].astype(float)
        historical_prices["adj_close"] = historical_prices["adj_close"].astype(float)
        historical_prices["volume"] = historical_prices["volume"].astype("Int64") 
        historical_prices["ticker"] = historical_prices["ticker"].astype(str)
        
        #añadir df a la lista
        all_data.append(historical_prices)
    
    #concatenar todos los dfs en uno solo
    combined_data = pd.concat(all_data, ignore_index=True)
    
    #guardar csv con el nombre del ticker y la fecha de extracción 
    file_name = f"historical_prices_{datetime.now().strftime('%Y%m%d')}.csv"
    combined_data.to_csv(file_name, index=False)
    
    return combined_data

# %%
df_historical_prices = get_historical_prices(tickers)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
df_historical_prices
# Out:
#              date        open        high         low       close   adj_close  \
# 0      1980-12-12    0.128348    0.128906    0.128348    0.128348    0.098943
# 1      1980-12-15    0.122210    0.122210    0.121652    0.121652    0.093781
# 2      1980-12-16    0.113281    0.113281    0.112723    0.112723    0.086898
# 3      1980-12-17    0.115513    0.116071    0.115513    0.115513    0.089049
# 4      1980-12-18    0.118862    0.119420    0.118862    0.118862    0.091630
# ...           ...         ...         ...         ...         ...         ...
# 40854  2024-10-24  173.320007  174.949997  172.910004  174.380005  174.380005
# 40855  2024-10-25  174.779999  176.289993  173.100006  173.520004  173.520004
# 40856  2024-10-28  174.050003  174.169998  172.139999  172.419998  172.419998
# 40857  2024-10-29  172.289993  174.020004  172.289993  173.429993  173.429993
# 40858  2024-10-30  173.979996  176.160004  172.789993  174.559998  174.559998
#
# ...

# %%
#datos de cuándo y cuánto ha pagado la empresa en dividendos

def get_dividends(tickers):
    all_data = []  #almacenar los df individuales de cada ticker
    
    for ticker in tickers:
        dividends = yf.Ticker(ticker).dividends
        dividends = dividends.reset_index()
        
        #añadir valor del ticker para todas las filas
        dividends["ticker"] = ticker
        
        #añadir timestamp
        extraction_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        dividends = pd.DataFrame(dividends)
        dividends["Extraction_Timestamp"] = extraction_time
        dividends["Extraction_Timestamp"] = pd.to_datetime(dividends["Extraction_Timestamp"])
        
        #renombrar las columnas
        dividends.columns = ["date", "dividends", "ticker", "extraction_timestamp"]
    
        #añadir df a la lista
        all_data.append(dividends)
    
    #concatenar todos los dfs en uno solo
    combined_data = pd.concat(all_data, ignore_index=True)
    
    #guardar csv con el nombre del ticker y la fecha de extracción    
    file_name = f"dividends_{datetime.now().strftime('%Y%m%d')}.csv"
    combined_data.to_csv(file_name, index=False)
    
    return combined_data

# %%
df_dividends = get_dividends(tickers)

# %%
df_dividends
# Out:
#                          date  dividends ticker extraction_timestamp
# 0   1987-05-11 00:00:00-04:00   0.000536   AAPL  2024-10-31 11:36:59
# 1   1987-08-10 00:00:00-04:00   0.000536   AAPL  2024-10-31 11:36:59
# 2   1987-11-17 00:00:00-05:00   0.000714   AAPL  2024-10-31 11:36:59
# 3   1988-02-12 00:00:00-05:00   0.000714   AAPL  2024-10-31 11:36:59
# 4   1988-05-16 00:00:00-04:00   0.000714   AAPL  2024-10-31 11:36:59
# ..                        ...        ...    ...                  ...
# 328 2023-10-11 00:00:00-04:00   0.400000   ORCL  2024-10-31 11:37:00
# 329 2024-01-10 00:00:00-05:00   0.400000   ORCL  2024-10-31 11:37:00
# 330 2024-04-09 00:00:00-04:00   0.400000   ORCL  2024-10-31 11:37:00
# 331 2024-07-11 00:00:00-04:00   0.400000   ORCL  2024-10-31 11:37:00
# 332 2024-10-10 00:00:00-04:00   0.400000   ORCL  2024-10-31 11:37:00
#
# [333 rows x 4 columns]

# %%
#datos de los splits, afectan a cómo se interpreta el precio histórico de las acciones

def get_splits(tickers):
    all_data = []  #almacenar los df individuales de cada ticker
    
    for ticker in tickers:
        splits = yf.Ticker(ticker).splits
        splits = splits.reset_index()
        
        #añadir valor del ticker para todas las filas
        splits["ticker"] = ticker
        
        #añadir timestamp
        extraction_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        splits = pd.DataFrame(splits)
        splits["Extraction_Timestamp"] = extraction_time
        splits["Extraction_Timestamp"] = pd.to_datetime(splits["Extraction_Timestamp"])
            
        #renombrar las columnas
        splits.columns = ["date", "splits", "ticker", "extraction_timestamp"]
    
        #añadir df a la lista
        all_data.append(splits)
    
    #concatenar todos los dfs en uno solo
    combined_data = pd.concat(all_data, ignore_index=True)
    
    #guardar csv con el nombre del ticker y la fecha de extracción    
    file_name = f"splits_{datetime.now().strftime('%Y%m%d')}.csv"
    combined_data.to_csv(file_name, index=False)
    
    return combined_data

# %%
df_splits = get_splits(tickers)

# %%
df_splits
# Out:
#                         date  splits ticker extraction_timestamp
# 0  1987-06-16 00:00:00-04:00     2.0   AAPL  2024-10-31 11:37:01
# 1  2000-06-21 00:00:00-04:00     2.0   AAPL  2024-10-31 11:37:01
# 2  2005-02-28 00:00:00-05:00     2.0   AAPL  2024-10-31 11:37:01
# 3  2014-06-09 00:00:00-04:00     7.0   AAPL  2024-10-31 11:37:01
# 4  2020-08-31 00:00:00-04:00     4.0   AAPL  2024-10-31 11:37:01
# 5  2000-06-27 00:00:00-04:00     2.0   NVDA  2024-10-31 11:37:01
# 6  2001-09-10 00:00:00-04:00     2.0   NVDA  2024-10-31 11:37:01
# 7  2006-04-07 00:00:00-04:00     2.0   NVDA  2024-10-31 11:37:01
# 8  2007-09-11 00:00:00-04:00     1.5   NVDA  2024-10-31 11:37:01
# 9  2021-07-20 00:00:00-04:00     4.0   NVDA  2024-10-31 11:37:01
# 10 2024-06-10 00:00:00-04:00    10.0   NVDA  2024-10-31 11:37:01
# 11 1987-09-21 00:00:00-04:00     2.0   MSFT  2024-10-31 11:37:02
# 12 1990-04-16 00:00:00-04:00     2.0   MSFT  2024-10-31 11:37:02
# ...

# %%
#datos de la estructura financiera de la empresa

def get_balance_sheet(tickers):
    all_data = []  #almacenar los df individuales de cada ticker
    
    for ticker in tickers:
        try:
            balance_sheet = yf.Ticker(ticker).balance_sheet.T
            balance_sheet = balance_sheet.reset_index()
            balance_sheet = balance_sheet.rename(columns={'index': 'Date'})
            
            #añadir valor del ticker para todas las filas
            balance_sheet["ticker"] = ticker
            
            #añadir timestamp
            extraction_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
            balance_sheet["extraction_timestamp"] = pd.to_datetime(extraction_time)
            
            #filtrado de columnas
            columns_needed = {
                "Date": "date",
                "ticker": "ticker",
                "Ordinary Shares Number": "ordinary_shares_number",
                "Net Debt": "net_debt",
                "Total Assets": "total_assets",
                "Current Liabilities": "current_liabilities",
                "Stockholders Equity": "stockholders_equity",
                "extraction_timestamp": "extraction_timestamp"
            }
            balance_sheet_filtered = balance_sheet[[col for col in columns_needed if col in balance_sheet.columns]]
            
            #renombrar las columnas
            balance_sheet_filtered = balance_sheet_filtered.rename(columns=columns_needed)
            
            #añadir df a la lista
            all_data.append(balance_sheet_filtered)
        
        except exception as e: #por si algun ticket da error
            print(f"Error en el {ticker}: {e}")
    
    #concatenar todos los dfs en uno solo
    combined_data = pd.concat(all_data, ignore_index=True)
    
    #guardar csv con el nombre del ticker y la fecha de extracción    
    file_name = f"balance_sheet_{datetime.now().strftime('%Y%m%d')}.csv"
    combined_data.to_csv(file_name, index=False)
    
    return combined_data

# %%
df_balance_sheet = get_balance_sheet(tickers)

# %%
df_balance_sheet
# Out:
#          date ticker ordinary_shares_number       net_debt    total_assets  \
# 0  2023-09-30   AAPL          15550061000.0  81123000000.0  352583000000.0
# 1  2022-09-30   AAPL          15943425000.0  96423000000.0  352755000000.0
# 2  2021-09-30   AAPL          16426786000.0  89779000000.0  351002000000.0
# 3  2020-09-30   AAPL          16976763000.0  74420000000.0  323888000000.0
# 4  2024-01-31   NVDA          24640000000.0   2429000000.0   65728000000.0
# 5  2023-01-31   NVDA          24661365720.0   7564000000.0   41182000000.0
# 6  2022-01-31   NVDA          25060000000.0   8956000000.0   44187000000.0
# 7  2021-01-31   NVDA          24800000000.0   6116000000.0   28791000000.0
# 8  2020-01-31   NVDA                    NaN            NaN             NaN
# 9  2024-06-30   MSFT           7434000000.0  33315000000.0  512163000000.0
# 10 2023-06-30   MSFT           7432000000.0  12533000000.0  411976000000.0
# ...

# %%
#estado de resultados, para entender la rentabilidad de la empresa a lo largo del tiempo

def get_income_statement(tickers):
    all_data = []  #almacenar los df individuales de cada ticker
    
    for ticker in tickers:
        income_statement = yf.Ticker(ticker).financials.T
        income_statement = income_statement.reset_index()
        income_statement = income_statement.rename(columns={'index': 'Date'})
        
        #añadir valor del ticker para todas las filas
        income_statement["ticker"] = ticker
        
        #añadir timestamp
        extraction_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        income_statement["Extraction_Timestamp"] = extraction_time
        income_statement["Extraction_Timestamp"] = pd.to_datetime(income_statement["Extraction_Timestamp"])
                
        #filtrar columnas
        income_statement_filtered = income_statement[["Date", "ticker", "EBITDA", "Total Revenue", "Net Income", "Operating Income", "Diluted EPS", "Extraction_Timestamp"]]
        
        #renombrar las columnas
        income_statement_filtered.columns = ["date", "ticker", "ebitda", "total_revenue", "net_income", "operating_income", "diluted_eps", "extraction_timestamp"]
    
        #añadir df a la lista
        all_data.append(income_statement_filtered)
    
    #concatenar todos los dfs en uno solo
    combined_data = pd.concat(all_data, ignore_index=True)
    
    #guardar csv con el nombre del ticker y la fecha de extracción    
    file_name = f"income_statement_{datetime.now().strftime('%Y%m%d')}.csv"
    combined_data.to_csv(file_name, index=False)
    
    return combined_data

# %%
df_income_statement = get_income_statement(tickers)

# %%
df_income_statement
# Out:
#          date ticker          ebitda   total_revenue     net_income  \
# 0  2023-09-30   AAPL  129188000000.0  383285000000.0  96995000000.0
# 1  2022-09-30   AAPL  133138000000.0  394328000000.0  99803000000.0
# 2  2021-09-30   AAPL  123136000000.0  365817000000.0  94680000000.0
# 3  2020-09-30   AAPL   81020000000.0  274515000000.0  57411000000.0
# 4  2024-01-31   NVDA   35583000000.0   60922000000.0  29760000000.0
# 5  2023-01-31   NVDA    5987000000.0   26974000000.0   4368000000.0
# 6  2022-01-31   NVDA   11351000000.0   26914000000.0   9752000000.0
# 7  2021-01-31   NVDA    5691000000.0   16675000000.0   4332000000.0
# 8  2024-06-30   MSFT  133009000000.0  245122000000.0  88136000000.0
# 9  2023-06-30   MSFT  105140000000.0  211915000000.0  72361000000.0
# 10 2022-06-30   MSFT  100239000000.0  198270000000.0  72738000000.0
# 11 2021-06-30   MSFT   85134000000.0  168088000000.0  61271000000.0
# 12 2023-10-31   AVGO   20554000000.0   35819000000.0  14082000000.0
# ...

# %%
#muestra cómo se genera y usa el efectivo, sirve para medir su salud financiera

def get_cashflow(tickers):
    all_data = []  #almacenar los df individuales de cada ticker
    
    for ticker in tickers:
        cashflow = yf.Ticker(ticker).cashflow.T
        cashflow = cashflow.reset_index()
        cashflow = cashflow.rename(columns={'index': 'Date'})
        
        #añadir valor del ticker para todas las filas
        cashflow["ticker"] = ticker
        
        #añadir timestamp
        extraction_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        cashflow["Extraction_Timestamp"] = extraction_time
        cashflow["Extraction_Timestamp"] = pd.to_datetime(cashflow["Extraction_Timestamp"])
        
        #filtrar columnas
        cashflow_filtered = cashflow[["Date", "ticker", "Operating Cash Flow", "Capital Expenditure", "Free Cash Flow", "Extraction_Timestamp"]]
        
        #renombrar las columnas
        cashflow_filtered.columns = ["date", "ticker", "operating_cash_flow", "capital_expenditure", "free_cash_flow", "extraction_timestamp"]
           
        #añadir df a la lista
        all_data.append(cashflow_filtered)
    
    #concatenar todos los dfs en uno solo
    combined_data = pd.concat(all_data, ignore_index=True)
    
    #guardar csv con el nombre del ticker y la fecha de extracción    
    file_name = f"cashflow_{datetime.now().strftime('%Y%m%d')}.csv"
    combined_data.to_csv(file_name, index=False)
    
    return combined_data

# %%
df_cashflow = get_cashflow(tickers)

# %%
df_cashflow
# Out:
#          date ticker operating_cash_flow capital_expenditure  free_cash_flow  \
# 0  2023-09-30   AAPL      110543000000.0      -10959000000.0   99584000000.0
# 1  2022-09-30   AAPL      122151000000.0      -10708000000.0  111443000000.0
# 2  2021-09-30   AAPL      104038000000.0      -11085000000.0   92953000000.0
# 3  2020-09-30   AAPL       80674000000.0       -7309000000.0   73365000000.0
# 4  2024-01-31   NVDA       28090000000.0       -1069000000.0   27021000000.0
# 5  2023-01-31   NVDA        5641000000.0       -1833000000.0    3808000000.0
# 6  2022-01-31   NVDA        9108000000.0        -976000000.0    8132000000.0
# 7  2021-01-31   NVDA        5822000000.0       -1128000000.0    4694000000.0
# 8  2020-01-31   NVDA                 NaN                 NaN             NaN
# 9  2024-06-30   MSFT      118548000000.0      -44477000000.0   74071000000.0
# 10 2023-06-30   MSFT       87582000000.0      -28107000000.0   59475000000.0
# ...

# %%
#identificación de las instituciones que tienen participaciones

def get_holders(tickers):
    all_data = []  #almacenar los df individuales de cada ticker
    
    for ticker in tickers:
        holders = yf.Ticker(ticker).institutional_holders
        
        #añadir valor del ticker para todas las filas
        holders["ticker"] = ticker
        
        #añadir timestamp
        extraction_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        holders["Extraction_Timestamp"] = extraction_time
        holders["Extraction_Timestamp"] = pd.to_datetime(holders["Extraction_Timestamp"])
    
        #renombrar las columnas
        holders.columns = ["date", "holder", "pct_held", "shares", "value", "ticker", "extraction_timestamp"]
        
        #añadir df a la lista
        all_data.append(holders)
    
    #concatenar todos los dfs en uno solo
    combined_data = pd.concat(all_data, ignore_index=True)
    
    #guardar csv con el nombre del ticker y la fecha de extracción    
    file_name = f"holders_{datetime.now().strftime('%Y%m%d')}.csv"
    combined_data.to_csv(file_name, index=False)
    
    return combined_data

# %%
df_holders = get_holders(tickers)

# %%
df_holders
# Out:
#          date                                      holder  pct_held  \
# 0  2023-06-30                          Vanguard Group Inc    0.0834
# 1  2023-06-30                              Blackrock Inc.    0.0665
# 2  2023-06-30                     Berkshire Hathaway, Inc    0.0586
# 3  2023-06-30                    State Street Corporation    0.0370
# 4  2023-06-30                                    FMR, LLC    0.0196
# 5  2023-06-30               Geode Capital Management, LLC    0.0186
# 6  2023-06-30               Price (T.Rowe) Associates Inc    0.0145
# 7  2023-06-30                              Morgan Stanley    0.0131
# 8  2022-12-31           Norges Bank Investment Management    0.0107
# 9  2023-06-30                  Northern Trust Corporation    0.0105
# 10 2024-03-31                          Vanguard Group Inc    0.8672
# 11 2024-03-31                              Blackrock Inc.    0.7408
# 12 2024-03-31                                    FMR, LLC    0.4679
# ...

# %%
#datos de los cambios en las calificaciones que los analistas financieros hacen sobre una acción

def get_upgrades_downgrades(tickers):
    all_data = []  #almacenar los df individuales de cada ticker
    
    for ticker in tickers:
        upgrades_downgrades = yf.Ticker(ticker).upgrades_downgrades
        upgrades_downgrades = upgrades_downgrades.reset_index()
        
        #añadir valor del ticker para todas las filas
        upgrades_downgrades["ticker"] = ticker
        
        #añadir timestamp
        extraction_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        upgrades_downgrades["Extraction_Timestamp"] = extraction_time
        upgrades_downgrades["Extraction_Timestamp"] = pd.to_datetime(upgrades_downgrades["Extraction_Timestamp"])
        
        #renombrar las columnas
        upgrades_downgrades.columns = ["date", "firm", "to_grade", "from_grade", "action", "ticker", "extraction_timestamp"]
            
        #añadir df a la lista
        all_data.append(upgrades_downgrades)
    
    #concatenar todos los dfs en uno solo
    combined_data = pd.concat(all_data, ignore_index=True)
    
    #guardar csv con el nombre del ticker y la fecha de extracción    
    file_name = f"upgrades_downgrades_{datetime.now().strftime('%Y%m%d')}.csv"
    combined_data.to_csv(file_name, index=False)
    
    return combined_data

# %%
df_upgrades_downgrades = get_upgrades_downgrades(tickers)

# %%
df_upgrades_downgrades
# Out:
#                     date                 firm     to_grade     from_grade  \
# 0    2024-10-25 16:17:57              Keybanc  Underweight  Sector Weight
# 1    2024-10-09 11:56:32        Piper Sandler      Neutral        Neutral
# 2    2024-10-03 17:20:35    B of A Securities          Buy            Buy
# 3    2024-10-01 15:58:30             Barclays  Underweight    Underweight
# 4    2024-09-25 14:27:12  New Street Research      Neutral        Neutral
# ...                  ...                  ...          ...            ...
# 3390 2012-03-21 15:02:00                  UBS          Buy
# 3391 2012-03-21 13:04:00     Societe Generale         Hold
# 3392 2012-03-21 11:03:00        Morgan Keegan   Outperform
# 3393 2012-03-21 10:46:00        Deutsche Bank         Hold
# 3394 2012-03-12 09:54:00            Jefferies         Hold            Buy
#
#      action ticker extraction_timestamp
# 0      down   AAPL  2024-10-31 11:37:05
# 1      reit   AAPL  2024-10-31 11:37:05
# ...

# %%
#identificación de las empresas del sector de tecnológico
sector = yf.Sector("technology").top_companies
sector = sector.reset_index().rename(columns={"index": "symbol"})
sector
# Out:
#    symbol                                          name rating  market weight
# 0    AAPL                                    Apple Inc.    Buy       0.186074
# 1    NVDA                            NVIDIA Corporation    Buy       0.181772
# 2    MSFT                         Microsoft Corporation    Buy       0.171015
# 3    AVGO                                 Broadcom Inc.    Buy       0.044540
# 4    ORCL                            Oracle Corporation    Buy       0.025725
# 5     CRM                              Salesforce, Inc.    Buy       0.015070
# 6     AMD                  Advanced Micro Devices, Inc.    Buy       0.012801
# 7     ACN                                 Accenture plc    Buy       0.012064
# 8    CSCO                           Cisco Systems, Inc.    Buy       0.011784
# 9    ADBE                                    Adobe Inc.    Buy       0.011394
# 10    NOW                              ServiceNow, Inc.    Buy       0.010458
# ...

# %%
#datos de las acciones del sector de tecnológico

tickers = [
    'AAPL', 'MSFT', 'GOOGL', 'AMZN', 'META', 'TSLA', 'NVDA', 'INTC', 'ADBE', 'CSCO',
    'ORCL', 'CRM', 'IBM', 'AMD', 'NFLX', 'PYPL', 'SQ', 'TWTR', 'SNPS', 'ATVI',"AAPL","MSFT",                          
    "AVGO","ORCL", "CRM","AMD",  "ACN", "CSCO", "ADBE", "IBM", "NOW", "QCOM", "TXN", "INTU",                                    
    "UBER", "AMAT", "ANET", "PANW", "MU", "ADP", "FI", "ADI", "INTC", "PLTR", "LRCX", "KLAC",                             
    "DELL", "APH", "MSI", "SNPS", "CRWD", "MRVL", "CDNS", "WDAY", "FTNT", "ADSK", "ROP", "NXPI",                       
    "TTD", "APP", "PAYX", "TEAM", "FIS", "FICO", "SQ", "TEL", "MSTR", "MPWR", "DDOG"  
]

stock_info = []

for ticker in tickers:
    stock = yf.Ticker(ticker)
    stock_data = {
        "ticker": ticker,
        "name": stock.info.get("longName", ""),
        "sector": stock.info.get("sector", ""),
        "industry": stock.info.get("industry", ""),
        "market_cap": stock.info.get("marketCap", ""),
        "full_time_employees": stock.info.get("fullTimeEmployees", ""),
        "marketStart": stock.info.get("regularMarketTime", None)  # Time in Unix
        
    }
    stock_info.append(stock_data)

stocks = pd.DataFrame(stock_info)

# Convert marketStart from Unix timestamp to human-readable date if needed
stocks["marketStart"] = pd.to_datetime(stocks["marketStart"], unit="s")

stocks
# Out:
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/ATVI?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=ATVI&crumb=ZPqPbUSAzP9
#    ticker                            name                  sector  \
# 0    AAPL                      Apple Inc.              Technology
# 1    MSFT           Microsoft Corporation              Technology
# 2   GOOGL                   Alphabet Inc.  Communication Services
# 3    AMZN                Amazon.com, Inc.       Consumer Cyclical
# 4    META            Meta Platforms, Inc.  Communication Services
# ..    ...                             ...                     ...
# 64     SQ                     Block, Inc.              Technology
# 65    TEL             TE Connectivity plc              Technology
# 66   MSTR      MicroStrategy Incorporated              Technology
# ...

# %%
#IPO (Initial Public Offering)
tech_tickers_ipo = {
    'AAPL': '1980-12-12',
    'MSFT': '1986-03-13',
    'GOOGL': '2004-08-19',
    'AMZN': '1997-05-15',
    'META': '2012-05-18',  
    'TSLA': '2010-06-29',
    'NVDA': '1999-01-22',
    'INTC': '1971-10-13',
    'ADBE': '1986-08-08',
    'CSCO': '1990-02-16',
    'ORCL': '1986-03-12',
    'CRM': '2004-06-23',
    'IBM': '1911-11-12',
    'AMD': '1972-09-18',
    'NFLX': '2002-05-23',
    'PYPL': '2015-07-20',
    'SQ': '2015-11-19',
    'TWTR': '2013-11-07',
    'SNPS': '2000-01-24',
    'ATVI': '2003-08-09',
    'AVGO': '2016-09-14',
    'NOW': '2012-06-28',
    'QCOM': '1991-07-11',
    'TXN': '1953-01-01',
    'INTU': '1993-03-24',
    'UBER': '2019-05-10',
    'AMAT': '1980-06-19',
    'ANET': '2015-06-27',
    'PANW': '2012-07-20',
    'MU': '1984-03-06',
    'ADP': '1961-10-13',
    'FI': 'NA', 
    'ADI': '2000-08-08',
    'PLTR': '2020-09-30',
    'LRCX': '1996-11-06',
    'KLAC': '1995-08-01',
    'DELL': '2018-12-28',  # IPO tras ser privado
    'APH': '2011-07-06',
    'MSI': '2006-12-01',
    'CRWD': '2019-09-20',
    'MRVL': '2000-11-17',
    'CDNS': '1983-03-29',
    'WDAY': '2012-10-09',
    'FTNT': '2009-08-06',
    'ADSK': '1985-12-12',
    'ROP': '2000-08-10',
    'NXPI': '2012-08-02',
    'TTD': '2016-09-21',
    'APP': 'NA', 
    'PAYX': '1971-08-14',
    'TEAM': '2018-09-25',
    'FIS': '1968-01-08',
    'FICO': '1986-04-04',
    'TEL': '2016-01-05',
    'MSTR': '2006-01-26',
    'MPWR': '2007-11-02',
    'DDOG': '2019-09-19',
}

data = []

for ticker, ipo_date in tech_tickers_ipo.items():
    stock = yf.Ticker(ticker)
    info = stock.info
    data.append({
        "ticker": ticker,
        "name": info.get("shortName", None),
        "sector": info.get("sector", None),
        "industry": info.get("industry", None),
        "market_cap": info.get("marketCap", None),
        "full_time_employees": info.get("fullTimeEmployees", None),
        "ipo_date": ipo_date if ipo_date != "NA" else None  # Use the manually defined IPO date
    })


df = pd.DataFrame(data)

df['ipo_date'] = pd.to_datetime(df['ipo_date'])

# Añadir la columna de Extraction_Timestamp
extraction_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
df["extraction_timestamp"] = extraction_time
df["extraction_timestamp"] = pd.to_datetime(df["extraction_timestamp"])

file_name = f"stocks_{datetime.now().strftime('%Y%m%d')}.csv"
df.to_csv(file_name)
# Out:
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/ATVI?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=ATVI&crumb=ZPqPbUSAzP9

# %%
df.head(10)
# Out:
#   ticker                   name                  sector  \
# 0   AAPL             Apple Inc.              Technology
# 1   MSFT  Microsoft Corporation              Technology
# 2  GOOGL          Alphabet Inc.  Communication Services
# 3   AMZN       Amazon.com, Inc.       Consumer Cyclical
# 4   META   Meta Platforms, Inc.  Communication Services
# 5   TSLA            Tesla, Inc.       Consumer Cyclical
# 6   NVDA     NVIDIA Corporation              Technology
# 7   INTC      Intel Corporation              Technology
# 8   ADBE             Adobe Inc.              Technology
# 9   CSCO    Cisco Systems, Inc.              Technology
#
#                          industry    market_cap  full_time_employees  \
# 0            Consumer Electronics  3.498463e+12             161000.0
# 1       Software - Infrastructure  3.215809e+12             228000.0
# 2  Internet Content & Information  2.145823e+12             181269.0
# ...

# %%
"""
Extra: localización de los holders

Intentamos obtenenr la latitud y longitud de cada holder utilizando tanto la API Nominatim junto con la biblioteca Geopy 
como la API de GoogleMaps para realizar la geocodificación, pero no devolvían resultados ya que no reconocía los nombres correctamente.
Optamos por hacer una búsqueda manual de la dirección, latitud y longitud de los headquarters de los 18 holders y crear un df y csv ad hoc.

"""
# Out:
# '\nExtra: localización de los holders\n\nIntentamos obtenenr la latitud y longitud de cada holder utilizando tanto la API Nominatim junto con la biblioteca Geopy \ncomo la API de GoogleMaps para realizar la geocodificación, pero no devolvían resultados ya que no reconocía los nombres correctamente.\nOptamos por hacer una búsqueda manual de la dirección, latitud y longitud de los headquarters de los 18 holders y crear un df y csv ad hoc.\n\n'

# %%
#creación diccionario datos de la ubicación de los holders

locations = [
    {"holder": "Bank of America Corporation", "latitude": 35.22787, "longitude": -80.84219, "headquarters": "100 North Tryon Street, Charlotte, NC 28255"},
    {"holder": "Berkshire Hathaway, Inc", "latitude": 41.25724, "longitude": -95.96544, "headquarters": "3555 Farnam Street, Omaha, NE 68131"},
    {"holder": "Blackrock Inc.", "latitude": 40.75443, "longitude": -73.99963, "headquarters": "50 Hudson Yards, New York, NY 10001"},
    {"holder": "Capital International Investors", "latitude": 34.05364, "longitude": -118.25315, "headquarters": "333 South Hope Street, Los Angeles, CA 90071"},
    {"holder": "Capital Research Global Investors", "latitude": 34.05364, "longitude": -118.25315, "headquarters": "333 South Hope Street, Los Angeles, CA 90071"},
    {"holder": "Capital World Investors", "latitude": 34.05364, "longitude": -118.25315, "headquarters": "333 South Hope Street, Los Angeles, CA 90071"},
    {"holder": "Charles Schwab Investment Management, Inc.", "latitude": 37.79507, "longitude": -122.39378, "headquarters": "211 Main Street, San Francisco, CA 94105"},
    {"holder": "First Eagle Investment Management, LLC", "latitude": 40.76328, "longitude": -73.97930, "headquarters": "1345 Avenue of the Americas, New York, NY 10105"},
    {"holder": "Fisher Asset Management, LLC", "latitude": 33.01812, "longitude": -96.84023, "headquarters": "6500 International Pkwy, Plano, TX 75093"},
    {"holder": "FMR, LLC", "latitude": 42.35174, "longitude": -71.05389, "headquarters": "245 Summer St, Boston, MA 02210"},
    {"holder": "Geode Capital Management, LLC", "latitude": 42.35390, "longitude": -71.05744, "headquarters": "100 Summer St, Boston, MA 02110"},
    {"holder": "JP Morgan Chase & Company", "latitude": 40.75621, "longitude": -73.97428, "headquarters": "270 Park Ave, New York, NY 10017"},
    {"holder": "Loomis Sayles & Company, LP", "latitude": 42.35239, "longitude": -71.05635, "headquarters": "One Financial Center, Boston, MA 02111"},
    {"holder": "Morgan Stanley", "latitude": 40.76003, "longitude": -73.98548, "headquarters": "1585 Broadway, New York, NY 10019"},
    {"holder": "Norges Bank Investment Management", "latitude": 59.90878, "longitude": 10.74239, "headquarters": "Bankplassen 2, 0107, 0151 Oslo"},
    {"holder": "Northern Trust Corporation", "latitude": 41.88123, "longitude": -87.63237, "headquarters": "50 S La Salle St, Chicago, IL 60604"},
    {"holder": "Price (T.Rowe) Associates Inc", "latitude": 39.28729, "longitude": -76.61279, "headquarters": "100 E Pratt St, Baltimore, MD 21202"},
    {"holder": "State Street Corporation", "latitude": 42.36270, "longitude": -71.06005, "headquarters": "1 Congress St, Boston, MA 02114"},
    {"holder": "Vanguard Group Inc", "latitude": 40.05139, "longitude": -75.50420, "headquarters": "100 Vanguard Blvd, Malvern, PA 19355"}
]

df_locations = pd.DataFrame(locations)

df_locations.to_csv("holder_locations.csv", index=False)

# %%
df_locations
# Out:
#                                         holder  latitude  longitude  \
# 0                  Bank of America Corporation  35.22787  -80.84219
# 1                      Berkshire Hathaway, Inc  41.25724  -95.96544
# 2                               Blackrock Inc.  40.75443  -73.99963
# 3              Capital International Investors  34.05364 -118.25315
# 4            Capital Research Global Investors  34.05364 -118.25315
# 5                      Capital World Investors  34.05364 -118.25315
# 6   Charles Schwab Investment Management, Inc.  37.79507 -122.39378
# 7       First Eagle Investment Management, LLC  40.76328  -73.97930
# 8                 Fisher Asset Management, LLC  33.01812  -96.84023
# 9                                     FMR, LLC  42.35174  -71.05389
# 10               Geode Capital Management, LLC  42.35390  -71.05744
# 11                   JP Morgan Chase & Company  40.75621  -73.97428
# 12                 Loomis Sayles & Company, LP  42.35239  -71.05635
# ...
