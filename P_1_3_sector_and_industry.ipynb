# %% [markdown]
# # Sector and Industry

# %%
import yfinance as yf
import pandas as pd
from datetime import datetime

# %%
tickers_names = {
    "XLC": "Communication Services",
    "XLY": "Consumer Discretionary",
    "XLP": "Consumer Staples",
    "XLE": "Energy",
    "XLF": "Financials",
    "XLV": "Health Care",
    "XLI": "Industrials",
    "XLB": "Materials",
    "XLRE": "Real Estate",
    "XLK": "Technology",
    "XLU": "Utilities",
}
def create_sector_dataframe(tickers_dict):
    df = pd.DataFrame(tickers_dict.items(), columns=['Ticker', 'Sector'])
    extraction_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    df["Extraction_Timestamp"] = extraction_time  
    return df

sector_dataframe = create_sector_dataframe(tickers_names)

df= sector_dataframe
file_name = f"ticker_sector{datetime.now().strftime('%Y%m%d')}.csv"
df.to_csv(file_name)

# %%
sectores = {
    "Technology": ["AAPL", "MSFT", "GOOGL"],
    "Financial Services": ["JPM", "BAC", "WFC"],
    "Healthcare": ["JNJ", "PFE", "MRK"],
    "Consumer Cyclical": ["AMZN", "TSLA", "NKE"],
    "Industrials": ["BA", "CAT", "GE"],
    "Communication Services": ["GOOGL", "FB", "NFLX"],
    "Consumer Defensive": ["KO", "PG", "WMT"],
    "Energy": ["XOM", "CVX", "BP"],
    "Basic Materials": ["BA", "NEM", "FCX"],
    "Real Estate": ["PLD", "SPG", "DLR"],
    "Utilities": ["DUK", "SO", "NEE"],
}

data = []

for sector, tickers in sectores.items():
    for ticker in tickers:
        try:
            stock = yf.Ticker(ticker)
            info = stock.info

            data.append({
                "Sector": sector,
                "Name": info.get('longName', 'N/A'),
                "Symbol": info.get('symbol', 'N/A'),
                "Ticker": ticker
            })
        except Exception as e:
            print(f"Error fetching data for {ticker}: {e}")

df = pd.DataFrame(data)

extraction_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
df["Extraction_Timestamp"] = extraction_time

file_name = f"company_sector{datetime.now().strftime('%Y%m%d')}.csv"
df.to_csv(file_name)

# %%
tech = yf.Sector("technology")

# %%
data = {
    'Tech Sector Info': {
        'Key': tech.key,
        'Name': tech.name,
        'Symbol': tech.symbol,
        'Ticker': tech.ticker,
        'Overview': tech.overview,
        'Top Companies': tech.top_companies,
        'Research Reports': tech.research_reports,
        'Top ETFs': tech.top_etfs,
        'Top Mutual Funds': tech.top_mutual_funds,
        'Industries': tech.industries,
    }}
data
# Out:
# {'Tech Sector Info': {'Key': 'technology',
#   'Name': 'Technology',
#   'Symbol': '^YH311',
#   'Ticker': yfinance.Ticker object <^YH311>,
#   'Overview': {'companies_count': 809,
#    'market_cap': 19178459234304,
#    'message_board_id': 'INDEXYH311',
#    'description': 'Companies engaged in the design, development, and support of computer operating systems and applications. This sector also includes companies that make computer equipment, data storage products, networking products, semiconductors, and components. Companies in this sector include Apple, Microsoft, and IBM.',
#    'industries_count': 12,
#    'market_weight': 0.29183847,
#    'employee_count': 7339636},
#   'Top Companies':                                                 name rating  market weight
#   symbol
#   AAPL                                      Apple Inc.    Buy       0.189459
#   NVDA                              NVIDIA Corporation    Buy       0.186012
#   MSFT                           Microsoft Corporation    Buy       0.167850
#   AVGO                                   Broadcom Inc.    Buy       0.044254
#   ORCL                              Oracle Corporation    Buy       0.025660
#   CRM                                 Salesforce, Inc.    Buy       0.014560
#   AMD                     Advanced Micro Devices, Inc.    Buy       0.013172
#   ACN                                    Accenture plc    Buy       0.012271
#   CSCO                             Cisco Systems, Inc.    Buy       0.011931
#   ADBE                                      Adobe Inc.    Buy       0.011466
#   IBM      International Business Machines Corporation   Hold       0.011300
#   QCOM                           QUALCOMM Incorporated    Buy       0.010190
#   NOW                                 ServiceNow, Inc.    Buy       0.009981
#   TXN                   Texas Instruments Incorporated   Hold       0.009347
#   INTU                                     Intuit Inc.    Buy       0.009025
#   UBER                         Uber Technologies, Inc.    Buy       0.008923
#   AMAT                         Applied Materials, Inc.    Buy       0.007969
#   ANET                           Arista Networks, Inc.    Buy       0.006581
#   PANW                        Palo Alto Networks, Inc.    Buy       0.006468
#   MU                           Micron Technology, Inc.    Buy       0.006314
#   ADP                  Automatic Data Processing, Inc.   Hold       0.006276
#   FI                                      Fiserv, Inc.    Buy       0.006072
#   ADI                             Analog Devices, Inc.    Buy       0.005891
#   PLTR                      Palantir Technologies Inc.   Hold       0.005079
#   INTC                               Intel Corporation   Hold       0.005059
#   LRCX                        Lam Research Corporation    Buy       0.004998
#   KLAC                                 KLA Corporation    Buy       0.004742
#   DELL                          Dell Technologies Inc.    Buy       0.004464
#   APH                             Amphenol Corporation    Buy       0.004252
#   MSI                         Motorola Solutions, Inc.    Buy       0.004144
#   SNPS                                  Synopsys, Inc.    Buy       0.004077
#   CRWD                      CrowdStrike Holdings, Inc.    Buy       0.003995
#   MRVL                        Marvell Technology, Inc.    Buy       0.003814
#   CDNS                    Cadence Design Systems, Inc.    Buy       0.003638
#   WDAY                                   Workday, Inc.    Buy       0.003454
#   FTNT                                  Fortinet, Inc.   Hold       0.003331
#   ADSK                                  Autodesk, Inc.    Buy       0.003284
#   ROP                         Roper Technologies, Inc.    Buy       0.003126
#   NXPI                         NXP Semiconductors N.V.    Buy       0.003115
#   TTD                             The Trade Desk, Inc.    Buy       0.003099
#   APP                             AppLovin Corporation    Buy       0.002806
#   PAYX                                   Paychex, Inc.   Hold       0.002687
#   TEAM                           Atlassian Corporation    Buy       0.002663
#   FICO                          Fair Isaac Corporation    Buy       0.002626
#   FIS     Fidelity National Information Services, Inc.    Buy       0.002579
#   SQ                                       Block, Inc.    Buy       0.002368
#   TEL                              TE Connectivity plc    Buy       0.002357
#   MSTR                      MicroStrategy Incorporated    Buy       0.002351
#   MPWR                  Monolithic Power Systems, Inc.    Buy       0.002258
#   DDOG                                   Datadog, Inc.    Buy       0.002219,
#   'Research Reports': [{'id': 'MS_0P000004VE_AnalystReport_1729644516000',
#     'headHtml': 'Analyst Report: Seagate Technology Holdings plc',
#     'provider': 'Morningstar',
#     'targetPrice': 78.0,
#     'targetPriceStatus': 'Increased',
#     'investmentRating': 'Bearish',
#     'reportDate': '2024-10-23T00:48:36Z',
#     'reportTitle': 'Seagate is a leading supplier of hard disk drives for data storage to the enterprise and consumer markets. It forms a practical duopoly in the market with its chief rival, Western Digital; they are both vertically integrated. ',
#     'reportType': 'Analyst Report'},
#    {'id': 'MS_0P0001BRCG_AnalystReport_1729637664000',
#     'headHtml': 'Analyst Report: MongoDB, Inc.',
#     'provider': 'Morningstar',
#     'targetPrice': 330.0,
#     'targetPriceStatus': 'Maintained',
#     'investmentRating': 'Bullish',
#     'reportDate': '2024-10-22T22:54:24Z',
#     'reportTitle': 'Founded in 2007, MongoDB is a document-oriented database with nearly 33,000 paying customers and well past 1.5 million free users. MongoDB provides both licenses as well as subscriptions as a service for its NoSQL database. MongoDB’s database is compatible with all major programming languages and is capable of being deployed for a variety of use cases. ',
#     'reportType': 'Analyst Report'},
#    {'id': 'MS_0P00000282_AnalystReport_1729611162000',
#     'headHtml': 'Analyst Report: Fiserv, Inc.',
#     'provider': 'Morningstar',
#     'targetPrice': 168.0,
#     'targetPriceStatus': 'Maintained',
#     'investmentRating': 'Bearish',
#     'reportDate': '2024-10-22T15:32:42Z',
#     'reportTitle': 'Fiserv is a leading provider of core processing and complementary services, such as electronic funds transfer, payment processing, and loan processing, for US banks and credit unions, with a focus on small and midsize banks. Through the merger with First Data in 2019, Fiserv also provides payment processing services for merchants. About 10% of the company’s revenue is generated internationally. ',
#     'reportType': 'Analyst Report'},
#    {'id': 'ARGUS_41589_MarketOutlook_1729595145000',
#     'headHtml': 'Daily Spotlight: Bitcoin ETFs: Is it time to invest?',
#     'provider': 'Argus Research',
#     'reportDate': '2024-10-22T11:05:45Z',
#     'reportTitle': "Not long ago, the only way to gain exposure to Bitcoin was to invest in it directly. The process was arduous and required self-service in an unregulated market. But investing in Bitcoin has come a long way thanks to the January debut of spot Bitcoin ETFs. This new type of security gives investors exposure to Bitcoin without the need to buy, store, or manage it. In less than a year, investors have shown their support by collectively pouring over $65 billion into these securities. Convenience isn't the only advantage. Bitcoin ETFs operate in regulated financial markets that provide a degree of security and transparency. They are offered by reputable asset managers, many of them household names, and the funds offer better liquidity than the underlying security. With the value of Bitcoin nearing $70,000, the ETFs have outperformed the S&P 500 since their inception. Despite the results, investors should be cautious. Like the underlying asset, Bitcoin ETFs come with volatility. The same funds that outperformed the S&P 500 on a year-to-date basis underperformed the index on a three-month and six-month basis. Should you invest in Bitcoin ETFs? While we expect the volatility of the underlying security to decline over time, that expectation remains speculative for now. The recent results demonstrate that Bitcoin ETFs may offer attractive returns for investors with a long-term investment horizon and high tolerance for risk. In the near-term, Argus believes there may be a place for Bitcoin ETFs with limited exposure in an aggressive diversified portfolio.",
#     'reportType': 'Market Outlook'}],
#   'Top ETFs': {'VGT': 'Vanguard Information Tech ETF',
#    'XLK': 'SPDR Select Sector Fund - Techn',
#    'SMH': 'VanEck Semiconductor ETF',
#    'IYW': 'iShares U.S. Technology ETF',
#    'SOXX': 'iShares Semiconductor ETF',
#    'FTEC': 'Fidelity MSCI Information Techn',
#    'SOXL': 'Direxion Daily Semiconductor Bu',
#    'IGV': 'iShares Expanded Tech-Software ',
#    'CIBR': 'First Trust NASDAQ Cybersecurit',
#    'IGM': 'iShares Expanded Tech Sector ET'},
#   'Top Mutual Funds': {'VITAX': 'Vanguard Information Technology',
#    'FDYNX': 'Franklin Dynatech Fund Class C',
#    'FDYZX': 'Franklin DynaTech Fund Class Ad',
#    'FDNRX': 'Franklin Dynatech Fd Cl R',
#    'FDTRX': 'Franlin DynaTech Fund Cl R6',
#    'FKDNX': 'Franklin Dynatech Fund Class A',
#    'FSELX': 'Fidelity Select Semiconductors ',
#    'FSPTX': 'Fidelity Select Technology',
#    'SCIRX': 'Columbia Seligman Communication',
#    'CCIFX': None},
#   'Industries':                                                                   name  \
#   key
#   semiconductors                                          Semiconductors
#   software-infrastructure                      Software - Infrastructure
#   consumer-electronics                              Consumer Electronics
#   software-application                            Software - Application
#   information-technology-services        Information Technology Services
#   communication-equipment                        Communication Equipment
#   semiconductor-equipment-materials  Semiconductor Equipment & Materials
#   computer-hardware                                    Computer Hardware
#   electronic-components                            Electronic Components
#   scientific-technical-instruments    Scientific & Technical Instruments
#   solar                                                            Solar
#   electronics-computer-distribution  Electronics & Computer Distribution
#
#                                           symbol  market weight
#   key
#   semiconductors                     ^YH31130020       0.296150
#   software-infrastructure            ^YH31110030       0.259181
#   consumer-electronics               ^YH31120030       0.187244
#   software-application               ^YH31110020       0.117980
#   information-technology-services    ^YH31110010       0.048121
#   communication-equipment            ^YH31120010       0.022693
#   semiconductor-equipment-materials  ^YH31130010       0.021990
#   computer-hardware                  ^YH31120020       0.019883
#   electronic-components              ^YH31120040       0.013033
#   scientific-technical-instruments   ^YH31120060       0.009509
#   solar                              ^YH31130030       0.002513
#   electronics-computer-distribution  ^YH31120050       0.001704  }}

# %%
top_companies= yf.Sector("technology").top_companies
df = pd.DataFrame(top_companies)
extraction_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
df["Extraction_Timestamp"] = extraction_time
#filename = f"stocks{datetime.now().strftime('%Y%m%d')}.csv"
#stocks.to_csv(file_name)


#df.to_csv("top_companies_tech.csv", index=False)
df
# Out:
#                                                 name rating  market weight  \
# symbol
# AAPL                                      Apple Inc.    Buy       0.189459
# NVDA                              NVIDIA Corporation    Buy       0.186012
# MSFT                           Microsoft Corporation    Buy       0.167850
# AVGO                                   Broadcom Inc.    Buy       0.044254
# ORCL                              Oracle Corporation    Buy       0.025660
# CRM                                 Salesforce, Inc.    Buy       0.014560
# AMD                     Advanced Micro Devices, Inc.    Buy       0.013172
# ACN                                    Accenture plc    Buy       0.012271
# CSCO                             Cisco Systems, Inc.    Buy       0.011931
# ADBE                                      Adobe Inc.    Buy       0.011466
# IBM      International Business Machines Corporation   Hold       0.011300
# QCOM                           QUALCOMM Incorporated    Buy       0.010190
# NOW                                 ServiceNow, Inc.    Buy       0.009981
# TXN                   Texas Instruments Incorporated   Hold       0.009347
# INTU                                     Intuit Inc.    Buy       0.009025
# UBER                         Uber Technologies, Inc.    Buy       0.008923
# AMAT                         Applied Materials, Inc.    Buy       0.007969
# ANET                           Arista Networks, Inc.    Buy       0.006581
# PANW                        Palo Alto Networks, Inc.    Buy       0.006468
# MU                           Micron Technology, Inc.    Buy       0.006314
# ADP                  Automatic Data Processing, Inc.   Hold       0.006276
# FI                                      Fiserv, Inc.    Buy       0.006072
# ADI                             Analog Devices, Inc.    Buy       0.005891
# PLTR                      Palantir Technologies Inc.   Hold       0.005079
# INTC                               Intel Corporation   Hold       0.005059
# LRCX                        Lam Research Corporation    Buy       0.004998
# KLAC                                 KLA Corporation    Buy       0.004742
# DELL                          Dell Technologies Inc.    Buy       0.004464
# APH                             Amphenol Corporation    Buy       0.004252
# MSI                         Motorola Solutions, Inc.    Buy       0.004144
# SNPS                                  Synopsys, Inc.    Buy       0.004077
# CRWD                      CrowdStrike Holdings, Inc.    Buy       0.003995
# MRVL                        Marvell Technology, Inc.    Buy       0.003814
# CDNS                    Cadence Design Systems, Inc.    Buy       0.003638
# WDAY                                   Workday, Inc.    Buy       0.003454
# FTNT                                  Fortinet, Inc.   Hold       0.003331
# ADSK                                  Autodesk, Inc.    Buy       0.003284
# ROP                         Roper Technologies, Inc.    Buy       0.003126
# NXPI                         NXP Semiconductors N.V.    Buy       0.003115
# TTD                             The Trade Desk, Inc.    Buy       0.003099
# APP                             AppLovin Corporation    Buy       0.002806
# PAYX                                   Paychex, Inc.   Hold       0.002687
# TEAM                           Atlassian Corporation    Buy       0.002663
# FICO                          Fair Isaac Corporation    Buy       0.002626
# FIS     Fidelity National Information Services, Inc.    Buy       0.002579
# SQ                                       Block, Inc.    Buy       0.002368
# TEL                              TE Connectivity plc    Buy       0.002357
# MSTR                      MicroStrategy Incorporated    Buy       0.002351
# MPWR                  Monolithic Power Systems, Inc.    Buy       0.002258
# DDOG                                   Datadog, Inc.    Buy       0.002219
#
#        Extraction_Timestamp
# symbol
# AAPL    2024-10-23 08:26:16
# NVDA    2024-10-23 08:26:16
# MSFT    2024-10-23 08:26:16
# AVGO    2024-10-23 08:26:16
# ORCL    2024-10-23 08:26:16
# CRM     2024-10-23 08:26:16
# AMD     2024-10-23 08:26:16
# ACN     2024-10-23 08:26:16
# CSCO    2024-10-23 08:26:16
# ADBE    2024-10-23 08:26:16
# IBM     2024-10-23 08:26:16
# QCOM    2024-10-23 08:26:16
# NOW     2024-10-23 08:26:16
# TXN     2024-10-23 08:26:16
# INTU    2024-10-23 08:26:16
# UBER    2024-10-23 08:26:16
# AMAT    2024-10-23 08:26:16
# ANET    2024-10-23 08:26:16
# PANW    2024-10-23 08:26:16
# MU      2024-10-23 08:26:16
# ADP     2024-10-23 08:26:16
# FI      2024-10-23 08:26:16
# ADI     2024-10-23 08:26:16
# PLTR    2024-10-23 08:26:16
# INTC    2024-10-23 08:26:16
# LRCX    2024-10-23 08:26:16
# KLAC    2024-10-23 08:26:16
# DELL    2024-10-23 08:26:16
# APH     2024-10-23 08:26:16
# MSI     2024-10-23 08:26:16
# SNPS    2024-10-23 08:26:16
# CRWD    2024-10-23 08:26:16
# MRVL    2024-10-23 08:26:16
# CDNS    2024-10-23 08:26:16
# WDAY    2024-10-23 08:26:16
# FTNT    2024-10-23 08:26:16
# ADSK    2024-10-23 08:26:16
# ROP     2024-10-23 08:26:16
# NXPI    2024-10-23 08:26:16
# TTD     2024-10-23 08:26:16
# APP     2024-10-23 08:26:16
# PAYX    2024-10-23 08:26:16
# TEAM    2024-10-23 08:26:16
# FICO    2024-10-23 08:26:16
# FIS     2024-10-23 08:26:16
# SQ      2024-10-23 08:26:16
# TEL     2024-10-23 08:26:16
# MSTR    2024-10-23 08:26:16
# MPWR    2024-10-23 08:26:16
# DDOG    2024-10-23 08:26:16

# %%
df["name"]
# Out:
# symbol
# AAPL                                      Apple Inc.
# NVDA                              NVIDIA Corporation
# MSFT                           Microsoft Corporation
# AVGO                                   Broadcom Inc.
# ORCL                              Oracle Corporation
# CRM                                 Salesforce, Inc.
# AMD                     Advanced Micro Devices, Inc.
# ACN                                    Accenture plc
# CSCO                             Cisco Systems, Inc.
# ADBE                                      Adobe Inc.
# IBM      International Business Machines Corporation
# QCOM                           QUALCOMM Incorporated
# NOW                                 ServiceNow, Inc.
# TXN                   Texas Instruments Incorporated
# INTU                                     Intuit Inc.
# UBER                         Uber Technologies, Inc.
# AMAT                         Applied Materials, Inc.
# ANET                           Arista Networks, Inc.
# PANW                        Palo Alto Networks, Inc.
# MU                           Micron Technology, Inc.
# ADP                  Automatic Data Processing, Inc.
# FI                                      Fiserv, Inc.
# ADI                             Analog Devices, Inc.
# PLTR                      Palantir Technologies Inc.
# INTC                               Intel Corporation
# LRCX                        Lam Research Corporation
# KLAC                                 KLA Corporation
# DELL                          Dell Technologies Inc.
# APH                             Amphenol Corporation
# MSI                         Motorola Solutions, Inc.
# SNPS                                  Synopsys, Inc.
# CRWD                      CrowdStrike Holdings, Inc.
# MRVL                        Marvell Technology, Inc.
# CDNS                    Cadence Design Systems, Inc.
# WDAY                                   Workday, Inc.
# FTNT                                  Fortinet, Inc.
# ADSK                                  Autodesk, Inc.
# ROP                         Roper Technologies, Inc.
# NXPI                         NXP Semiconductors N.V.
# TTD                             The Trade Desk, Inc.
# APP                             AppLovin Corporation
# PAYX                                   Paychex, Inc.
# TEAM                           Atlassian Corporation
# FICO                          Fair Isaac Corporation
# FIS     Fidelity National Information Services, Inc.
# SQ                                       Block, Inc.
# TEL                              TE Connectivity plc
# MSTR                      MicroStrategy Incorporated
# MPWR                  Monolithic Power Systems, Inc.
# DDOG                                   Datadog, Inc.
# Name: name, dtype: object

# %%
top_ETFs = yf.Sector("technology").top_etfs
print(type(top_ETFs))
print(top_ETFs)
if isinstance(top_ETFs, dict):
    df = pd.DataFrame.from_dict(top_ETFs, orient='index').reset_index()
elif isinstance(top_ETFs, list):
    df = pd.DataFrame(top_ETFs)
else:
    raise ValueError("top_ETFs no es un formato compatible para crear un DataFrame.")


extraction_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
df["Extraction_Timestamp"] = extraction_time

df.to_csv("top_etfs_tech.csv", index=False)
df
# Out:
# <class 'dict'>
# {'VGT': 'Vanguard Information Tech ETF', 'XLK': 'SPDR Select Sector Fund - Techn', 'SMH': 'VanEck Semiconductor ETF', 'IYW': 'iShares U.S. Technology ETF', 'SOXX': 'iShares Semiconductor ETF', 'FTEC': 'Fidelity MSCI Information Techn', 'SOXL': 'Direxion Daily Semiconductor Bu', 'IGV': 'iShares Expanded Tech-Software ', 'CIBR': 'First Trust NASDAQ Cybersecurit', 'IGM': 'iShares Expanded Tech Sector ET'}
#   index                                0 Extraction_Timestamp
# 0   VGT    Vanguard Information Tech ETF  2024-10-23 09:09:12
# 1   XLK  SPDR Select Sector Fund - Techn  2024-10-23 09:09:12
# 2   SMH         VanEck Semiconductor ETF  2024-10-23 09:09:12
# 3   IYW      iShares U.S. Technology ETF  2024-10-23 09:09:12
# 4  SOXX        iShares Semiconductor ETF  2024-10-23 09:09:12
# 5  FTEC  Fidelity MSCI Information Techn  2024-10-23 09:09:12
# 6  SOXL  Direxion Daily Semiconductor Bu  2024-10-23 09:09:12
# 7   IGV  iShares Expanded Tech-Software   2024-10-23 09:09:12
# 8  CIBR  First Trust NASDAQ Cybersecurit  2024-10-23 09:09:12
# 9   IGM  iShares Expanded Tech Sector ET  2024-10-23 09:09:12

# %%
industry =yf.Sector("technology").industries
df=pd.DataFrame(industry)
extraction_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
df["Extraction_Timestamp"] = extraction_time
file_name = f"industry{datetime.now().strftime('%Y%m%d')}.csv"
df.to_csv(file_name)
